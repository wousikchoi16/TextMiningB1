# %% [markdown]
# # Chapter 10. RNN - 딥러닝을 이용한 문서 분류
#
# ## 10.3. RNN을 이용한 문서 분류 - NLTK 영화 리뷰 감성분석
#
# ### 10.3.1 워드 임베딩을 위한 데이터 준비

# %%
from nltk.corpus import movie_reviews
fileids = movie_reviews.fileids() #movie review data에서 file id를 가져옴
reviews = [movie_reviews.raw(fileid) for fileid in fileids] #file id를 이용해 raw text file을 가져옴
categories = [movie_reviews.categories(fileid)[0] for fileid in fileids] 
#file id를 이용해 label로 사용할 category 즉 positive와 negative 정보를 순서대로 가져옴

print('Reviews count:', len(reviews))
print('Length of the first review:', len(reviews[0]))
print('Labels:', set(categories))
# Out:
# Reviews count: 2000
# Length of the first review: 4043
# Labels: {'pos', 'neg'}

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
np.random.seed(7)
tf.random.set_seed(7)

max_words = 10000 #사용할 단어의 수

# 빈도가 높은 10000개의 단어를 선택하도록 객체 생성
tokenizer = Tokenizer(num_words=max_words, oov_token='UNK') 

tokenizer.fit_on_texts(reviews) #단어 인덱스 구축

#만들어진 단어 인덱스를 이용해 문서들을 변환
X = tokenizer.texts_to_sequences(reviews) 

print('Lengths of first 10 documents:', [len(doc) for doc in X[:10]])
# Out:
# Lengths of first 10 documents: [710, 240, 486, 479, 733, 671, 550, 584, 702, 776]

# %%
tokenizer.word_index['UNK']
# Out:
# 1

# %%
X[0] # reviews[0] = 글 에 대해서 단어를 숫자로 바꾼 묶음!
# Out:
# [98,
#  77,
#  949,
#  4622,
#  131,
#  6,
#  3,
#  2016,
#  789,
#  3764,
#  4,
#  103,
#  1314,
#  37,
#  73,
#  56,
#  25,
#  1341,
#  24,
#  5,
#  2,
#  519,
#  1325,
#  17,
#  14,
#  678,
#  1571,
#  6,
#  84,
#  55,
#  8,
#  34,
#  90,
#  4,
#  33,
#  4477,
#  604,
#  2,
#  638,
#  242,
#  2,
#  27,
#  4,
#  8854,
#  190,
#  41,
#  2186,
#  3,
#  302,
#  6462,
#  27,
#  13,
#  2,
#  949,
#  1458,
#  9,
#  2402,
#  20,
#  3,
#  80,
#  691,
#  362,
#  17,
#  1768,
#  10,
#  8,
#  3,
#  80,
#  106,
#  3980,
#  46,
#  7,
#  49,
#  143,
#  15,
#  466,
#  25,
#  57,
#  3668,
#  24,
#  6,
#  1175,
#  195,
#  19,
#  1342,
#  8855,
#  96,
#  46,
#  527,
#  6,
#  831,
#  2,
#  7098,
#  903,
#  12,
#  170,
#  363,
#  4,
#  118,
#  342,
#  4204,
#  8856,
#  17,
#  53,
#  21,
#  62,
#  4,
#  106,
#  753,
#  5,
#  243,
#  36,
#  2695,
#  5,
#  96,
#  4,
#  113,
#  1879,
#  51,
#  249,
#  1,
#  15,
#  24,
#  6180,
#  37,
#  250,
#  6,
#  32,
#  625,
#  15,
#  272,
#  3765,
#  1224,
#  17,
#  2795,
#  10,
#  2284,
#  40,
#  49,
#  21,
#  2,
#  470,
#  12,
#  2,
#  27,
#  78,
#  65,
#  349,
#  354,
#  7,
#  9,
#  38,
#  322,
#  89,
#  7840,
#  10,
#  437,
#  88,
#  1315,
#  17,
#  103,
#  1,
#  56,
#  15,
#  1446,
#  146,
#  8,
#  46,
#  35,
#  11,
#  25,
#  162,
#  1123,
#  32,
#  60,
#  362,
#  604,
#  160,
#  20,
#  53,
#  21,
#  1077,
#  53,
#  21,
#  82,
#  505,
#  136,
#  29,
#  2,
#  329,
#  53,
#  21,
#  486,
#  28,
#  178,
#  39,
#  2,
#  329,
#  53,
#  21,
#  770,
#  1,
#  53,
#  21,
#  1,
#  53,
#  21,
#  3,
#  1,
#  5,
#  911,
#  115,
#  53,
#  21,
#  5278,
#  5,
#  1387,
#  172,
#  9,
#  633,
#  4,
#  64,
#  5,
#  10,
#  7,
#  322,
#  26,
#  1958,
#  144,
#  19,
#  2927,
#  121,
#  302,
#  255,
#  6,
#  9490,
#  3,
#  16,
#  151,
#  144,
#  4,
#  103,
#  17,
#  45,
#  36,
#  10,
#  92,
#  7,
#  257,
#  104,
#  2,
#  165,
#  2852,
#  101,
#  4,
#  101,
#  209,
#  19,
#  73,
#  260,
#  5,
#  4078,
#  43,
#  83,
#  3,
#  95,
#  46,
#  7,
#  15,
#  248,
#  955,
#  354,
#  38,
#  614,
#  295,
#  15,
#  134,
#  802,
#  6,
#  3147,
#  17,
#  10,
#  139,
#  6,
#  258,
#  6,
#  3147,
#  10,
#  309,
#  314,
#  65,
#  370,
#  494,
#  227,
#  4,
#  76,
#  37,
#  87,
#  172,
#  440,
#  2796,
#  47,
#  57,
#  1748,
#  8,
#  2,
#  5676,
#  26,
#  93,
#  2,
#  1281,
#  205,
#  7,
#  9,
#  2,
#  4079,
#  4,
#  19,
#  159,
#  5677,
#  20,
#  1712,
#  39,
#  15,
#  40,
#  63,
#  176,
#  4080,
#  64,
#  5,
#  10,
#  41,
#  22,
#  2,
#  269,
#  85,
#  213,
#  40,
#  36,
#  5,
#  2,
#  1,
#  83,
#  9,
#  198,
#  443,
#  6,
#  87,
#  3,
#  99,
#  252,
#  5,
#  262,
#  17,
#  10,
#  138,
#  249,
#  2,
#  87,
#  2,
#  16,
#  36,
#  9,
#  44,
#  440,
#  19,
#  619,
#  2,
#  1487,
#  312,
#  12,
#  122,
#  39,
#  15,
#  7,
#  9,
#  35,
#  168,
#  246,
#  87,
#  277,
#  9,
#  2,
#  162,
#  7,
#  56,
#  10,
#  57,
#  142,
#  37,
#  21,
#  285,
#  2,
#  802,
#  1,
#  6,
#  2017,
#  170,
#  146,
#  5,
#  2330,
#  19,
#  571,
#  964,
#  7841,
#  1,
#  427,
#  222,
#  29,
#  3864,
#  13,
#  42,
#  1431,
#  227,
#  458,
#  2,
#  27,
#  7,
#  51,
#  1685,
#  3593,
#  1124,
#  63,
#  73,
#  10,
#  53,
#  21,
#  102,
#  3025,
#  34,
#  4,
#  63,
#  121,
#  119,
#  28,
#  37,
#  21,
#  76,
#  63,
#  93,
#  438,
#  6,
#  84,
#  10,
#  101,
#  4,
#  101,
#  209,
#  97,
#  42,
#  666,
#  133,
#  317,
#  115,
#  3289,
#  1045,
#  2441,
#  56,
#  36,
#  5,
#  2,
#  1,
#  160,
#  150,
#  8,
#  2,
#  27,
#  683,
#  2,
#  930,
#  875,
#  15,
#  16,
#  222,
#  29,
#  65,
#  124,
#  4,
#  1,
#  10,
#  43,
#  492,
#  4,
#  10,
#  337,
#  53,
#  8857,
#  70,
#  3,
#  272,
#  876,
#  949,
#  302,
#  6462,
#  27,
#  8,
#  129,
#  1103,
#  17,
#  19,
#  619,
#  2,
#  2853,
#  1326,
#  9,
#  1730,
#  10,
#  56,
#  3,
#  290,
#  432,
#  12,
#  99,
#  1327,
#  69,
#  87,
#  44,
#  262,
#  2,
#  210,
#  21,
#  272,
#  62,
#  13,
#  2,
#  64,
#  205,
#  188,
#  2595,
#  1,
#  51,
#  676,
#  6,
#  23,
#  389,
#  2,
#  2110,
#  165,
#  75,
#  9,
#  18,
#  198,
#  8,
#  259,
#  1035,
#  58,
#  8,
#  3,
#  114,
#  5279,
#  17,
#  107,
#  955,
#  5280,
#  131,
#  41,
#  6,
#  1,
#  28,
#  1544,
#  34,
#  182,
#  458,
#  2,
#  340,
#  16,
#  4,
#  176,
#  33,
#  35,
#  622,
#  34,
#  1527,
#  1,
#  899,
#  2,
#  16,
#  117,
#  1994,
#  86,
#  10,
#  117,
#  2477,
#  38,
#  1472,
#  10,
#  1359,
#  1,
#  4,
#  10,
#  649,
#  272,
#  7099,
#  13,
#  64,
#  5,
#  65,
#  1,
#  401,
#  3,
#  272,
#  691,
#  325,
#  4,
#  1995,
#  6,
#  36,
#  5,
#  2,
#  1,
#  9,
#  771,
#  142,
#  10,
#  658,
#  4,
#  22,
#  2,
#  85,
#  15,
#  7,
#  26,
#  3,
#  296,
#  47,
#  949,
#  1650,
#  732,
#  38,
#  51,
#  1,
#  6,
#  178,
#  9,
#  85,
#  86,
#  372,
#  7,
#  683,
#  6793,
#  9,
#  2,
#  522,
#  7,
#  138,
#  1133,
#  12,
#  2,
#  441,
#  10,
#  72,
#  3211,
#  461,
#  77,
#  175,
#  715,
#  4,
#  33,
#  70,
#  1488,
#  20,
#  2,
#  7444,
#  194,
#  195,
#  1046,
#  2854,
#  10,
#  3981,
#  4205,
#  505,
#  29,
#  3,
#  2215,
#  5,
#  7100,
#  1004,
#  641,
#  1212,
#  303,
#  1447,
#  1316,
#  315,
#  1212,
#  303,
#  2,
#  2519,
#  1854,
#  303,
#  2,
#  2519,
#  7101,
#  750,
#  303,
#  342,
#  4204,
#  303,
#  303,
#  8856,
#  303,
#  303,
#  2,
#  486,
#  1854,
#  303,
#  4342,
#  5,
#  3865,
#  1023,
#  303]

# %%
print("Index of 'the':", tokenizer.word_index["the"])
print("Index of 'review':", tokenizer.word_index["review"])
print("Index of out-of-vocabulary words:", tokenizer.word_index["UNK"])
# Out:
# Index of 'the': 2
# Index of 'review': 466
# Index of out-of-vocabulary words: 1

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

maxlen = 500 #문서의 단어 수를 제한

# 문서의 단어 수가 500보다 작으면 0을 채우고, 크면 잘라냄
# 잘라낼 때, 앞을 자를 지, 뒤를 자를 지 선택할 수 있음. 앞을 자르고 뒷부분을 쓰고자 하면 'pre' 선택
X = pad_sequences(X, maxlen=maxlen, truncating='pre')

# %%
import numpy as np

# label을 0, 1의 값으로 변환
label_dict = {'pos':1, 'neg':0}
y = np.array([label_dict[c] for c in categories])
print(set(y))
print(y) #참고용
# Out:
# {0, 1}
# [0 0 0 ... 1 1 1]

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

print('Train set count:', len(X_train))
print('Test set count:', len(X_test))
print('Test data:',X_test[0:20])
print('Test samples:', y_test[:20])
# Out:
# Train set count: 1600
# Test set count: 400
# Test data: [[6190    2  495 ...  132   30   36]
#  [  40   71    9 ...  503 2368 6005]
#  [   0    0    0 ...   13    2    1]
#  ...
#  [   3  114  296 ...    5   65 1836]
#  [ 506    2 9210 ...    1 5739 9218]
#  [   0    0    0 ...   13    3  216]]
# Test samples: [0 1 1 0 1 1 0 0 0 0 1 1 0 0 1 0 0 1 1 1]

# %% [markdown]
# ### 10.3.2 RNN이 아닌 일반적인 신경망 모형을 이용한 분류

# %%
# 케라스 모형 생성 및 학습
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Embedding

model = Sequential([ #순차적 모형
    Embedding(max_words, 32, input_length=maxlen), #word embedding layer 생성
    # max_words는 one-hot encoding을 할 때의 vector 크기가 됨 - 사용된 단어의 수만큼
    # 각 단어는 32 크기의 dense vector로 embedding 됨
    # input_length는 한 document의 단어 수로 표현
    # 이 과정을 거치면 각 document는 (maxlen, 32)의 2차원 행렬이 됨 - 즉 word의 sequence가 됨

    Flatten(), # 2차원 행렬을 1차원으로 펼침
    Dense(1, activation='sigmoid') #binary logistic regression을 수행
])

model.summary() #모델의 요약정보 출력
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 32)           320000
#
#  flatten (Flatten)           (None, 16000)             0
#
#  dense (Dense)               (None, 1)                 16001
#
# =================================================================
# Total params: 336,001
# Trainable params: 336,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모형의 optimizer와 loss function 등을 지정
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
# 학습을 수행
history = model.fit(X_train, y_train, 
                    epochs=10,
                    verbose=1,
                    validation_split=0.2)
# Out:
# Epoch 1/10
# 40/40 [==============================] - 1s 9ms/step - loss: 0.6913 - acc: 0.5281 - val_loss: 0.6858 - val_acc: 0.5688
# Epoch 2/10
# 40/40 [==============================] - 0s 6ms/step - loss: 0.5859 - acc: 0.9234 - val_loss: 0.6737 - val_acc: 0.6156
# Epoch 3/10
# 40/40 [==============================] - 0s 6ms/step - loss: 0.4473 - acc: 0.9773 - val_loss: 0.6494 - val_acc: 0.6406
# Epoch 4/10
# 40/40 [==============================] - 0s 6ms/step - loss: 0.2894 - acc: 0.9945 - val_loss: 0.6198 - val_acc: 0.6469
# Epoch 5/10
# 40/40 [==============================] - 0s 6ms/step - loss: 0.1608 - acc: 0.9984 - val_loss: 0.5920 - val_acc: 0.6844
# Epoch 6/10
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0786 - acc: 0.9992 - val_loss: 0.5762 - val_acc: 0.6719
# Epoch 7/10
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0348 - acc: 1.0000 - val_loss: 0.5645 - val_acc: 0.6938
# Epoch 8/10
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0140 - acc: 1.0000 - val_loss: 0.5629 - val_acc: 0.7094
# Epoch 9/10
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0053 - acc: 1.0000 - val_loss: 0.5585 - val_acc: 0.7094
# Epoch 10/10
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 0.5805 - val_acc: 0.7188

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def plot_results(history, metric):
    plt.plot(history.history[metric], 'b', label='Training '+metric)
    plt.plot(history.history['val_'+metric], 'r--', label='Validation '+metric)
    plt.title('Training vs. Validation '+metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric)
    plt.legend()
    plt.show()

plot_results(history, 'acc')

# %%
#테스트 셋으로 학습된 모형의 성능을 평가
score = model.evaluate(X_test, y_test)
print(f'#Test accuracy:{score[1]:.3f}')
# Out:
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5605 - acc: 0.7225
# #Test accuracy:0.723

# %%
X_test.shape
# Out:
# (400, 500)

# %%
y_test.shape
# Out:
# (400,)

# %% [markdown]
# ### 10.3.3 문서의 순서정보를 활용하는 RNN 기반 문서분류

# %%
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Embedding(max_words, 32),
    SimpleRNN(32), # 펼쳐서 flat하게 만드는 대신 RNN 모형을 사용, maxlen만큼의 시계열 데이터
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()

adam = Adam(learning_rate=1e-4)
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, 
                    epochs=10,
                    verbose=1,
                    validation_split=0.2)

plot_results(history, 'acc')
#테스트 셋으로 학습된 모형의 성능을 평가
score = model.evaluate(X_test, y_test)
print(f'#Test accuracy:{score[1]:.3f}')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 32)          320000
#
#  simple_rnn (SimpleRNN)      (None, 32)                2080
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 323,169
# Trainable params: 323,169
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 40/40 [==============================] - 28s 692ms/step - loss: 0.6965 - acc: 0.4953 - val_loss: 0.6961 - val_acc: 0.4875
# Epoch 2/10
# 40/40 [==============================] - 27s 685ms/step - loss: 0.6821 - acc: 0.5813 - val_loss: 0.6970 - val_acc: 0.4719
# Epoch 3/10
# 40/40 [==============================] - 28s 702ms/step - loss: 0.6681 - acc: 0.6367 - val_loss: 0.6980 - val_acc: 0.4625
# Epoch 4/10
# 40/40 [==============================] - 27s 688ms/step - loss: 0.6502 - acc: 0.7109 - val_loss: 0.6999 - val_acc: 0.4594
# Epoch 5/10
# 40/40 [==============================] - 27s 681ms/step - loss: 0.6291 - acc: 0.7547 - val_loss: 0.7010 - val_acc: 0.4656
# Epoch 6/10
# 40/40 [==============================] - 27s 686ms/step - loss: 0.5999 - acc: 0.8156 - val_loss: 0.7042 - val_acc: 0.4625
# Epoch 7/10
# 40/40 [==============================] - 28s 692ms/step - loss: 0.5609 - acc: 0.8648 - val_loss: 0.7076 - val_acc: 0.4656
# Epoch 8/10
# 40/40 [==============================] - 27s 688ms/step - loss: 0.5177 - acc: 0.9000 - val_loss: 0.7113 - val_acc: 0.4906
# Epoch 9/10
# 40/40 [==============================] - 63s 2s/step - loss: 0.4589 - acc: 0.9297 - val_loss: 0.7218 - val_acc: 0.4719
# Epoch 10/10
# 40/40 [==============================] - 65s 2s/step - loss: 0.3984 - acc: 0.9555 - val_loss: 0.7329 - val_acc: 0.4875
# 13/13 [==============================] - 3s 171ms/step - loss: 0.6972 - acc: 0.5325
# #Test accuracy:0.533

# %% [markdown]
# ## 10.4. LSTM, Bi-LSTM과 GRU를 이용한 성능 개선

# %%
from tensorflow.keras.layers import LSTM, Bidirectional

model = Sequential([
    Embedding(max_words, 64),
    Bidirectional(LSTM(64)), # simple RNN 대신 bidirectional LSTM을 사용
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()

from tensorflow.keras.optimizers import Adam
adam = Adam(learning_rate=1e-4)
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['acc'])

# history = model.fit(X_train, y_train, epochs=8,verbose=1,  validation_split=0.2)

model.fit(X_train, y_train, epochs=8,verbose=1,  validation_split=0.2)

plot_results(history, 'acc')

#테스트 셋으로 학습된 모형의 성능을 평가
score = model.evaluate(X_test, y_test)
print(f'#Test accuracy:{score[1]:.3f}')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 64)          640000
#
#  bidirectional (Bidirectiona  (None, 128)              66048
#  l)
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 714,369
# Trainable params: 714,369
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/8
# 40/40 [==============================] - 15s 127ms/step - loss: 0.6931 - acc: 0.5055 - val_loss: 0.6929 - val_acc: 0.5188
# Epoch 2/8
# 40/40 [==============================] - 3s 77ms/step - loss: 0.6918 - acc: 0.5711 - val_loss: 0.6927 - val_acc: 0.5250
# Epoch 3/8
# 40/40 [==============================] - 3s 76ms/step - loss: 0.6901 - acc: 0.6000 - val_loss: 0.6923 - val_acc: 0.5250
# Epoch 4/8
# 40/40 [==============================] - 3s 76ms/step - loss: 0.6872 - acc: 0.6117 - val_loss: 0.6913 - val_acc: 0.5281
# Epoch 5/8
# 40/40 [==============================] - 3s 76ms/step - loss: 0.6796 - acc: 0.6633 - val_loss: 0.6847 - val_acc: 0.5813
# Epoch 6/8
# 40/40 [==============================] - 3s 77ms/step - loss: 0.6130 - acc: 0.7414 - val_loss: 0.6231 - val_acc: 0.7437
# Epoch 7/8
# 40/40 [==============================] - 3s 76ms/step - loss: 0.4660 - acc: 0.8500 - val_loss: 0.5131 - val_acc: 0.7375
# Epoch 8/8
# 40/40 [==============================] - 3s 77ms/step - loss: 0.3065 - acc: 0.8938 - val_loss: 0.5104 - val_acc: 0.7625
# 13/13 [==============================] - 3s 49ms/step - loss: 0.5256 - acc: 0.7550
# #Test accuracy:0.755

# %%
# model.predict()는 확률값을 예측 -> 반올림하여 0과 1로 만듬
y_pred = np.round(model.predict(X_test[:10])) 
for pred, y_t in zip(y_pred, y_test[:10]):
    print(f'predicted value: {pred[0]}, true value: {y_t}, so the prediction is {pred[0] == y_t}')
# Out:
# predicted value: 1.0, true value: 0, so the prediction is False
# predicted value: 0.0, true value: 1, so the prediction is False
# predicted value: 1.0, true value: 1, so the prediction is True
# predicted value: 1.0, true value: 0, so the prediction is False
# predicted value: 1.0, true value: 1, so the prediction is True
# predicted value: 1.0, true value: 1, so the prediction is True
# predicted value: 0.0, true value: 0, so the prediction is True
# predicted value: 1.0, true value: 0, so the prediction is False
# predicted value: 0.0, true value: 0, so the prediction is True
# predicted value: 0.0, true value: 0, so the prediction is True

# %%
print(y_pred)
# Out:
# [[1.]
#  [0.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]
#  [0.]]
